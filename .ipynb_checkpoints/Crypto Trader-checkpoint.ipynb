# %% [markdown]
# ### Data
# ETH Data hourly and minute all the way from at least 2020-11-22
# - https://www.cryptodatadownload.com/data/bitstamp/

# %%
import cbpro
from datetime import datetime, timedelta
import pandas as pd
from matplotlib import pyplot
from scipy import stats
import numpy as np

import math

## Coinbase
api_secret_key = "0jnqr8UOn8Bl07bKtX1CQvAYn43ShKqG8zuECRv6B4GTK/H0o5zK5eLSSbCcMpC56+5FMAsT/+z+y2iDHYj3vQ=="
client = cbpro.PublicClient()

# Tokens we will collect
tokens = ['AAVE-BTC',
 'ADA-BTC',
 'ALGO-BTC',
 'ANKR-BTC',
 'ATOM-BTC',
 'BAL-BTC',
 'BAND-BTC',
 'BAT-BTC',
 'BCH-BTC',
 'BNT-BTC',
 'BSV-BTC',
 'BTC-BTC',
 '"Celo',
 ' (CGLD)-BTC"',
 'COMP-BTC',
 'CRV-BTC',
 'CTSI-BTC',
 'CVC-BTC',
 'DAI-BTC',
 'DASH-BTC',
 'DNT-BTC',
 'ENJ-BTC',
 'EOS-BTC',
 'ETC-BTC',
 'ETH-BTC',
 'FORTH-BTC',
 'FIL-BTC',
 'GRT-BTC',
 'GNT-BTC',
 'ICP-BTC',
 'KNC-BTC',
 'LINK-BTC',
 'LOOM-BTC',
 'LRC-BTC',
 'LTC-BTC',
 'MANA-BTC',
 'MATIC-BTC',
 'MIR-BTC',
 'MKR-BTC',
 'NMR-BTC',
 'NKN-BTC',
 'NU-BTC',
 'OGN-BTC',
 'OMG-BTC',
 'OXT-BTC',
 'REN-BTC',
 'REP-BTC',
 'RLC-BTC',
 'SUSHI-BTC',
 'SKL-BTC',
 'SNX-BTC',
 'STORJ-BTC',
 'TRB-BTC',
 'USDC-BTC',
 'USDT-BTC',
 'UMA-BTC',
 'UNI-BTC',
 'WBTC-BTC',
 'XLM-BTC',
 'XRP-BTC',
 'XTZ-BTC',
 'YFI-BTC',
 'ZEC-BTC',
 'ZRX-BTC',
 '1INCH-BTC']

# data = pd.DataFrame()
# granularity = 21600
# days = 220
# for token in tokens:
#     print(token)
#     data = data.append(getData(client, granularity, token, days))
# data.to_csv("coinbaseData.csv")
# Out:
# AAVE-BTC
# ADA-BTC
# ALGO-BTC
# ANKR-BTC
# ATOM-BTC
# BAL-BTC
# BAND-BTC
# BAT-BTC
# BCH-BTC
# BNT-BTC
# BSV-BTC
# BTC-BTC
# "Celo
#  (CGLD)-BTC"
# COMP-BTC
# CRV-BTC
# CTSI-BTC
# CVC-BTC
# DAI-BTC
# DASH-BTC
# DNT-BTC
# ENJ-BTC
# EOS-BTC
# ETC-BTC
# ETH-BTC
# FORTH-BTC
# FIL-BTC
# GRT-BTC
# GNT-BTC
# ICP-BTC
# KNC-BTC
# LINK-BTC
# LOOM-BTC
# LRC-BTC
# LTC-BTC
# MANA-BTC
# MATIC-BTC
# MIR-BTC
# MKR-BTC
# NMR-BTC
# NKN-BTC
# NU-BTC
# OGN-BTC
# OMG-BTC
# OXT-BTC
# REN-BTC
# REP-BTC
# RLC-BTC
# SUSHI-BTC
# SKL-BTC
# SNX-BTC
# STORJ-BTC
# TRB-BTC
# USDC-BTC
# USDT-BTC
# UMA-BTC
# UNI-BTC
# WBTC-BTC
# XLM-BTC
# XRP-BTC
# XTZ-BTC
# YFI-BTC
# ZEC-BTC
# ZRX-BTC
# 1INCH-BTC

# %%
def getData(client, granularity, ticker, days):
    # lower bound for the date
    lowerBound = datetime.now() - timedelta(days=days)
    
    # number of data points per day
    splits = 24 / (granularity / 60 / 60)
    
    # number of days we can get data for (data segments)
    day_calls = 200 / splits
    
    end = datetime.now()
    start = end - timedelta(days=day_calls)
    data = []
    for _ in range(math.ceil(days // day_calls)):
        next = client.get_product_historic_rates(ticker, start=start, end=end, granularity=granularity)
        data.extend(next)
        start -= timedelta(days=day_calls)
        end -= timedelta(days=day_calls)
    try:
        data = pd.DataFrame(data, columns=["time", "low", "high", "open", "close", "volume"])
        data['ticker'] = ticker
        data['date'] = pd.to_datetime(data['time'],unit='s')
        return data
    
    except:
        return pd.DataFrame()

def getRank(data, ticker, lowerBound, skip):
    try:
        df = data[data['ticker'] == ticker].iloc[skip:lowerBound]
        df['percentChange'] = 100 * ((df['close'] - df['open']) / df['open'])
        reg = stats.linregress(df['time'].values, df['percentChange'].values)
        return (token, reg.rvalue, reg.slope, reg.rvalue ** 2 * reg.slope)
    except:
        return None

# %%
data = pd.read_csv("coinbaseData.csv")

# %%
holding_period = 4 * 2
amount = 10000
lowerDayBound = 150 * 4
skip = 125 * 4
openCloseIndex = skip - 4 * 15
wallet = {}
for i in range(10):
    ranks = []
    for token in tokens:
        rank = getRank(data, token, lowerDayBound, skip)
        if rank:
            ranks.append(rank)
    
    ranks.sort(key=lambda x : x[3], reverse=True)
    
    amount = 0 if len(wallet) else 10000
    for coin in wallet:
        amount += wallet[coin] * data[data['ticker'] == coin].iloc[openCloseIndex]['open']
    print(amount)
    
    # Get top 5 coins
    wallet = {}
    for i in range(5):
        coin = ranks[i][0]
        wallet[coin] = (amount * .2) / data[data['ticker'] == coin].iloc[openCloseIndex]['open']

    openCloseIndex -= holding_period
    lowerDayBound -= holding_period
    skip -= holding_period
# Out:
# 10000
# 10017.313604654002
# 9405.333923902714
# 11756.33352802313
# 11957.40379008738
# 17538.12477329519
# 18821.065537594906
# 18121.942162271698
# 18160.526626158015
# 24381.729981011817

# %%
data[data['ticker'] == "AAVE-BTC"]
# Out:
#      Unnamed: 0        time       low      high      open     close    volume  \
# 0             0  1621101600  0.010847  0.011297  0.011053  0.011059  3592.016
# 1             1  1621080000  0.011044  0.011634  0.011423  0.011047  3303.582
# 2             2  1621058400  0.011333  0.011759  0.011759  0.011414  2493.858
# 3             3  1621036800  0.011542  0.012192  0.011929  0.011773  3218.298
# 4             4  1621015200  0.011615  0.012185  0.012014  0.011925  2884.803
# ..          ...         ...       ...       ...       ...       ...       ...
# 601         601  1608120000  0.004017  0.004352  0.004134  0.004226  3049.166
# 602         602  1608098400  0.004115  0.004457  0.004230  0.004134  1282.513
# 603         603  1608076800  0.004163  0.004600  0.004489  0.004230   954.719
# 604         604  1608055200  0.004323  0.004600  0.004531  0.004489   402.593
# 605         605  1608033600  0.004503  0.004544  0.004508  0.004525   123.708
#
#        ticker                 date
# 0    AAVE-BTC  2021-05-15 18:00:00
# 1    AAVE-BTC  2021-05-15 12:00:00
# 2    AAVE-BTC  2021-05-15 06:00:00
# 3    AAVE-BTC  2021-05-15 00:00:00
# 4    AAVE-BTC  2021-05-14 18:00:00
# ..        ...                  ...
# 601  AAVE-BTC  2020-12-16 12:00:00
# 602  AAVE-BTC  2020-12-16 06:00:00
# 603  AAVE-BTC  2020-12-16 00:00:00
# 604  AAVE-BTC  2020-12-15 18:00:00
# 605  AAVE-BTC  2020-12-15 12:00:00
#
# [606 rows x 9 columns]
